# %% [markdown]
# ## O dataset
#
# O dataset a ser utilizado é o *IBM HR Analytics Employee Attrition & Performance*, disponível no Kaggle. O dataset contém informações sobre funcionários de uma empresa fictícia, como idade, gênero, estado civil, nível de satisfação, entre outros. O objetivo é prever a probabilidade de um funcionário sair da empresa.
#
# [Link do Kaggle](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/data)
#
# Os termos *attrition* ("atrito") e *turnover* ("rotatividade") são frequentemente usados de forma intercambiável no contexto de recursos humanos e gestão de força de trabalho, mas eles se referem a conceitos ligeiramente diferentes em relação às mudanças no número e na composição dos empregados dentro de uma organização. Compreender a distinção entre esses dois é importante para analisar e relatar com precisão a dinâmica da força de trabalho.
#
# ### Atrito
#
# Atrito refere-se à redução gradual de empregados por meio de circunstâncias naturais, como aposentadoria, demissão voluntária por motivos pessoais, ou a decisão de não substituir empregados que estão de saída. Atrito pode levar a uma diminuição no tamanho da força de trabalho, mas é caracterizado por sua natureza voluntária e muitas vezes incontrolável. Organizações podem permitir o atrito para reduzir o tamanho de sua força de trabalho sem recorrer a demissões, vendo isso como uma forma menos disruptiva de ajustar seus níveis de pessoal.
#
# Em análises, quando você está analisando um conjunto de dados para atrito, você frequentemente olha para as razões por trás das saídas voluntárias e a taxa na qual estas ocorrem naturalmente ao longo do tempo. Taxas de atrito podem fornecer insights sobre a satisfação dos empregados e tendências de longo prazo da força de trabalho.
#
# ### Rotatividade
#
# Rotatividade, por outro lado, engloba um escopo mais amplo de partidas de empregados, incluindo tanto renúncias voluntárias quanto demissões involuntárias (como demissões ou términos por justa causa). Porém, ocorre a substituição da força de trabalho. Rotatividade é uma medida de quantos empregados estão deixando a companhia por qualquer motivo. Uma alta taxa de rotatividade pode indicar problemas com satisfação no trabalho, cultura do local de trabalho, ou estabilidade organizacional, e frequentemente requer ação da gestão para endereçar as causas subjacentes.
#
# Rotatividade é calculada dividindo o número de empregados que saem pelo número médio de empregados, geralmente em uma base anual, e expressando isso como uma porcentagem. Esta métrica é crucial para entender como as saídas de empregados, tanto voluntárias quanto involuntárias, afetam a capacidade da organização de manter uma força de trabalho estável e eficaz.
#
# ### Diferenças Chave
#
# - **Natureza**: Atrito geralmente é voluntário e pode ser devido a fatores naturais ou incontroláveis, enquanto rotatividade inclui tanto saídas voluntárias quanto demissões involuntárias.
# - **Implicações para Gestão**: Atrito pode ser parte de uma estratégia de ajuste natural da força de trabalho e nem sempre é negativo, enquanto alta rotatividade é frequentemente um sinal de problemas dentro da organização que precisam ser abordados.
# - **Foco Estratégico**: Análise de atrito pode focar em entender tendências de longo prazo da força de trabalho e planejamento de aposentadoria, enquanto análise de rotatividade é frequentemente usada para identificar questões imediatas com satisfação de empregados, engajamento, ou práticas de gestão que podem estar impactando a retenção de staff.
#
# Enquanto ambos atrito e rotatividade lidam com empregados deixando a organização, eles diferem em seu escopo e as implicações estratégicas para gerenciar e entender a dinâmica da força de trabalho. No seu conjunto de dados de empregados, distinguir entre atrito e rotatividade pode ajudar na customização de estratégias para planejamento da força de trabalho, retenção e desenvolvimento organizacional.

# %% [markdown]
# |    | Name                       | Description                                                                                                                                                    |
# |---:|:---------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | Age                        | Numerical Value                                                                                                                                                |
# |  1 | Attrition                  | Employee leaving the company - Text - No, Yes                                                                                                                     |
# |  2 | BusinessTravel            | Text - Non-Travel, Travel_Frequently, Travel_Rarely                                                                                                             |
# |  3 | DailyRate                 | Numerical Value - Salary Level                                                                                                                                 |
# |  4 | Department                 | Text - Sales, Research & Development, Human Resources                                                                                                         |
# |  5 | DistanceFromHome         | Numerical Value - the distance from work to home in miles
# |  6 | Education                  | Numerical Value - 1=Below college, 2=College, 3=Bachelor, 4=Master, 5=PhD   |
# |  7 | EducationField            | Text - Life Sciences, Medical, Marketing, Techincal Degree, Human Resources, Other                                                                                   |
# |  8 | EmployeeCount             | Numerical Value - 1                                                                                                                                               |
# |  9 | EmployeeNumber            | Numerical Value - Employee ID                                                                                                                                  |
# | 10 | EnvironmentSatisfaction    | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High |
# | 11 | Gender                     | Text - Female, Male                                                                                                                                             |
# | 12 | HourlyRate                | Numerical Value - Hourly Salary                                                                                                                                |
# | 13 | JobInvolvement            | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 14 | JobLevel                  | Numerical Value - 1, 2, 3, 4, 5. Means different job levels                                                                                                     |
# | 15 | JobRole                   | Text - Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources |
# | 16 | JobSatisfaction           | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 17 | MaritalStatus             | Text - Single, Married, Divorced                                                                                                                                      |
# | 18 | MonthlyIncome             | Numerical Value - Monthly Salary                                                                                                                               |
# | 19 | MonthlyRate                | Numerical Value - Monthly Rate                                                                                                                                  |
# | 20 | NumCompaniesWorked        | Numerical Value - Number of companies worked at                                                                                                                |
# | 21 | Over18                    | Text - Y                                                                                                                                                    |
# | 22 | Overtime                   | Text - No, Yes                                                                                                                                                    |
# | 23 | PercentSalaryHike        | Numerical Value - Percentage increase in salary                                                                                                                |
# | 24 | PerformanceRating         | Numerical Value - 1=Low, 2=Good, 3=Excellent, 4=Outstanding                                                                                                    |
# | 25 | RelationshipSatisfaction  | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 26 | StandardHours             | Numerical Value - 80                                                                                                                                            |
# | 27 | StockOptionsLevel        | Numerical Value - 0, 1, 2, 3                                                                                                                                    |
# | 28 | TotalWorkingYears        | Numerical Value - Total years worked                                                                                                                            |
# | 29 | TrainingTimesLastYear   | Numerical Value - How many times the employee has been trained last year                                                                                       |
# | 30 | WorkLifeBalance          | Numerical Value - 1=Bad, 2=Good, 3=Better, 4=Best                                                                                                              |
# | 31 | YearsAtCompany           | Numerical Value - Number of years at the company                                                                                                                |
# | 32 | YearsInCurrentRole      | Numerical Value -Number of years in current role                                                                                                                |
# | 33 | YearsSinceLastPromotion | Numerical Value - Years since last promotion                                                                                                                    |
# | 34 | YearsWithCurrManager | Numerical Value - Years with current manager                                                                                                                    |

# %% [markdown]
# ## Checagens básicas

# %% [markdown]
# - shape
# - colunas
# - tipos
# - valores nulos
# - valores "estranhos"
# - valores únicos
# - valores duplicados
# - contagem de valores relevantes

# %%
import pandas as pd

DADOS = 'employee_attrition.csv'

df = pd.read_csv(DADOS)

df.head()

# Para relembrar estamos analisando a funcionarios em termo de ATRITO nesse projeto
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# comando para mostrar todas as 35 colunas, na tabela tem ... entre as colunas para abreviar
with pd.option_context('display.max_columns', 35):
    display(df.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
# fazendo uma checagem de shape
df.shape
# Out:
# (1470, 35)

# %%
# informacoes, interessante verificar se o Dtype esta de acordo com os dados fornecidos na tabela .csv
# caso o dtype esteja diferente e necessario fazer uma transformacao
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# nao ha necessidade de todas os 0`s da tabela acima
with pd.option_context('float_format', '{:.2f}'.format, 'display.max_columns', 35):
    display(df.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# ...

# %%
# hora de checar os valores aconselha se a olhar o valor minimo na tabela (min) para verificar se tem valores negativos. Nesse caso se a idade minima
# fosse 10, seria estranho. Tbm verificar numeros 0 que podem indicar algo errado ou NAO. Olhar max tbm para ver se faz sentidp, passando o olho( ver se os valores max
#condiz.
# Olhando o desvio por exemplo pode verificar que o desv padrao da coluna Employee Count = o pois todas as demais sao 1 entao nao existe desvio padrao. Nesse caso pode se 
# considerar em eliminar essa coluna pois nao tras nenhum info. A coluna StandardHours tbm tem desvio 0.

# %%
# Para verificar Outlier em qquer coluna e necesssario pegar o Q3 - Q1 e multiplica por 1.5. Na coluna Age:
1.5 * (43-30)
# Out:
# 19.5

# %%
30 - 1.5 * (43-30)
# A idade minima e 18 anos, nao existe idade 10.5 entao ta ok
# Out:
# 10.5

# %%
43 + 1.5 * (43-30)
# A idade max e 60 anos entao nao tem ninguem com 62.5. Conclusao nao ha outliers na coluna Age.
# Out:
# 62.5

# %%
# Agora faremos com DistanceFromHome(miles)
1.5 * (14 - 2)
# Out:
# 18.0

# %%
2 - 1.5 * (14 - 2)
# valor negativo entao esta ok
# Out:
# -16.0

# %%
14 + 1.5 * (14 - 2)
# Tbm nao e um outlier pois e menor que 29. Conclusao, coluna DistanceFromHome nao contem outliers.
# Out:
# 32.0

# %%
# Agora verificar TotalWorkingYears
1.5 * (15 - 6)
# Out:
# 13.5

# %%
6 - 1.5 * (15 - 6)
# Tudo ok pois tem valores negativos
# Out:
# -7.5

# %%
# Agora na parte de cima
15 + 1.5 * (15 - 6)
#  28.5 esta abaixo de 40 entao e considerado um valor outlier
# Out:
# 28.5

# %%
# Agora fazer o mesmo com as colunas nao numericas

df.describe(exclude='number')

# Na coluna Attrition por exemplo, tem 1233 com valores No, ou seja a imensa maioria
# Coluna Over18 e meio irrelevante podendo se livrar dela eventualmente
# Para relembrar estamos analisando a funcionarios em termo de ATTRITION (nossa coluna target)
# nesse caso podemos afirmar que a trata se de um dataset desbalanceado considerando que na coluna Attrition tem muito mais NO. Ou seja, qtd de funcionarios que sairam da
# empresa e muito menor que a qtd q permaneceram, podendo influenciar uma analise de machine learning que e muito mais tendencioso.
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
# valores nulos, ja aviamos verificado no info(). Mas podemos ingualmente para usar mais claro, usar:

df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Devemos remover colunas EmployeeNumber pois a coluna irrelevante no ponto de vista de analise. Aqui faremos apenas uma analise
# para verificar se sao unicos pois caso contrario pode demonstrar IDs duplicados resutado de um erro no sistema de registro.
# So fazendo esse codigo por curiosidade, nao tem efeito no projeto.

df['EmployeeNumber'].nunique()

# 1470 indica que sao todos nulos. Se fosse um valor menor indicaria que teria numeros repetidos tendo mais de uma linha
# duplicada, tendo um mesmo o mesmo funcionario com registro diferente o que seria um problema.
# Out:
# 1470

# %%
# remover colunas com valores unicos. Pode criar uma nova variavel ou subscrever. Vamos subescrever.
# vamos tbm remover EmployeeNumber pois a coluna irrelevante no ponto de vista de analise (cell acima).

df = df.drop(["EmployeeCount", "Over18", "StandardHours", "EmployeeNumber"], axis=1) # axis= 1 para indicar que e um eixo de coluna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
# registrar os 10 mais velhos e mais novos na empresa

df[df["Age"] == df["Age"].max()]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 411                  7          3  Life Sciences                        1
# 427                 28          3      Marketing                        3
# 536                 16          4      Marketing                        1
# 879                  7          4      Marketing                        2
# 1209                 1          4        Medical                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# ...

# %%
# registrar os 10 menos velhos e mais novos na empresa

df[df["Age"] == df["Age"].min()]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 727    18        No         Non-Travel        287  Research & Development
# 828    18       Yes         Non-Travel        247  Research & Development
# 972    18        No         Non-Travel       1124  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 1311   18        No         Non-Travel       1431  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 296                  3          3  Life Sciences                        3
# 301                 10          3        Medical                        4
# 457                  5          3      Marketing                        2
# ...

# %%
# para achar o 10 mais..

df.nlargest(10, 'Age')
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 63     59        No      Travel_Rarely       1435                   Sales
# 70     59        No  Travel_Frequently       1225                   Sales
# 105    59        No         Non-Travel       1420         Human Resources
# 225    59        No      Travel_Rarely        142  Research & Development
#
#       DistanceFromHome  Education   EducationField  EnvironmentSatisfaction  \
# 411                  7          3    Life Sciences                        1
# ...

# %%
# para achar o 10 menos..

df.nsmallest(10, 'Age')
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 727    18        No         Non-Travel        287  Research & Development
# 828    18       Yes         Non-Travel        247  Research & Development
# 972    18        No         Non-Travel       1124  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 1311   18        No         Non-Travel       1431  Research & Development
# 127    19       Yes      Travel_Rarely        528                   Sales
# 149    19        No      Travel_Rarely       1181  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 296                  3          3  Life Sciences                        3
# ...

# %%
# para achar o 10 mais tempo de companhia..

df.nlargest(10, 'YearsAtCompany')
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 126    58       Yes  Travel_Rarely        147  Research & Development
# 98     58        No  Travel_Rarely        682                   Sales
# 270    55        No  Travel_Rarely        452  Research & Development
# 1116   55        No  Travel_Rarely        685                   Sales
# 561    52        No  Travel_Rarely        621                   Sales
# 190    52        No  Travel_Rarely        699  Research & Development
# 237    52        No     Non-Travel        771                   Sales
# 914    55        No     Non-Travel        177  Research & Development
# 962    51        No  Travel_Rarely        770         Human Resources
# 1111   53       Yes  Travel_Rarely        607  Research & Development
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 126                 23          4           Medical                        4
# ...

# %%
# para achar o 10 menos tempo de companhia..

df.nsmallest(10, 'YearsAtCompany')
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 2     37       Yes      Travel_Rarely       1373  Research & Development
# 23    21        No      Travel_Rarely        391  Research & Development
# 77    45        No      Travel_Rarely        193  Research & Development
# 86    23        No      Travel_Rarely        541                   Sales
# 109   22        No      Travel_Rarely        534  Research & Development
# 127   19       Yes      Travel_Rarely        528                   Sales
# 171   19       Yes  Travel_Frequently        602                   Sales
# 264   28       Yes      Travel_Rarely        529  Research & Development
# 265   29        No      Travel_Rarely       1210                   Sales
# 296   18       Yes      Travel_Rarely        230  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 2                   2          2             Other                        4
# ...

# %%
# mais tempo no cargo sem promocao

df.nlargest(10, 'YearsSinceLastPromotion')
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 45    41       Yes  Travel_Rarely       1360  Research & Development
# 123   51        No  Travel_Rarely        684  Research & Development
# 126   58       Yes  Travel_Rarely        147  Research & Development
# 178   46        No  Travel_Rarely        526                   Sales
# 237   52        No     Non-Travel        771                   Sales
# 425   50        No  Travel_Rarely       1099  Research & Development
# 701   53        No  Travel_Rarely       1376                   Sales
# 752   36       Yes  Travel_Rarely        885  Research & Development
# 861   46        No  Travel_Rarely       1402                   Sales
# 914   55        No     Non-Travel        177  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 45                 12          3  Technical Degree                        2
# ...

# %%
# menos tempo no cargo sem promocao

df.nlargest(10, 'YearsSinceLastPromotion')
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 45    41       Yes  Travel_Rarely       1360  Research & Development
# 123   51        No  Travel_Rarely        684  Research & Development
# 126   58       Yes  Travel_Rarely        147  Research & Development
# 178   46        No  Travel_Rarely        526                   Sales
# 237   52        No     Non-Travel        771                   Sales
# 425   50        No  Travel_Rarely       1099  Research & Development
# 701   53        No  Travel_Rarely       1376                   Sales
# 752   36       Yes  Travel_Rarely        885  Research & Development
# 861   46        No  Travel_Rarely       1402                   Sales
# 914   55        No     Non-Travel        177  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 45                 12          3  Technical Degree                        2
# ...

# %%
# Para nao olhar todos as informacoes mas apenas queremos faremos um filtro com os parametros abaixo para YearsSinceLastPromotion:

df.nlargest(10, 'YearsSinceLastPromotion')[['Age', 'JobRole', 'YearsSinceLastPromotion', 'JobLevel']]

# De acordo com o resultado abaoixo, chama atencao que a maioria e de Roles de diretoria oque esplicaria o tempo desde a ultima promocao mas 
# principalmente a Lab Technician, talvez por ser so nivel tecnico ao algo assim nao recebeu promocao nos ultimos anos.
# Out:
#      Age                    JobRole  YearsSinceLastPromotion  JobLevel
# 45    41          Research Director                       15         5
# 123   51          Research Director                       15         5
# 126   58  Healthcare Representative                       15         3
# 178   46            Sales Executive                       15         3
# 237   52                    Manager                       15         5
# 425   50                    Manager                       15         4
# 701   53                    Manager                       15         4
# 752   36      Laboratory Technician                       15         1
# 861   46                    Manager                       15         4
# 914   55  Healthcare Representative                       15         4

# %%
# pessoas que recentemente receberam uma promocao. Aqui pode se ver algumas pessoas mais novas que e compreensivel ja que
# e a primeira promocao. MAs o que me chamou atencao mesmo foi ver que na tabela anterior tem uma Lab Technician que recebeu a ultima
#promocao ha 15 anos atras e esta no JobLevel 1 assim como a maioria do que receberam recentemente promocao tbm esta. P q sera que esta pessoa 
#nao recebeu aumento e continua no nivel 1 depois de tantos anos? Obs. sao algumas duvidas depende muito tbm entender sobre a area de RH...

df.nsmallest(10, 'YearsSinceLastPromotion')[['Age', 'JobRole', 'YearsSinceLastPromotion', 'JobLevel']]
# Out:
#     Age                JobRole  YearsSinceLastPromotion  JobLevel
# 0    41        Sales Executive                        0         2
# 2    37  Laboratory Technician                        0         1
# 6    59  Laboratory Technician                        0         1
# 7    30  Laboratory Technician                        0         1
# 10   35  Laboratory Technician                        0         1
# 11   29  Laboratory Technician                        0         2
# 14   28  Laboratory Technician                        0         1
# 16   32     Research Scientist                        0         1
# 17   22  Laboratory Technician                        0         1
# 21   36   Sales Representative                        0         1

# %%
# para fazer agrupamentos normalmente escolhemos colunas que tem pouco valores dentro delas como Absolutas, e textos. As continuas
# como salarios nessse caso tem muito valores diferentes entao nao faz mas sentido fazer agrupamentos. Tbm algumas colunas tem categorias (1-5)
# como por exemplo Education e EnvironmentSatisfaction.

df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# businesstravel, genero , educacao sao examplo das colunas de categorias nao ordenadas. Vamos separar as colunas de acordo com os grupos
# abaixo:

colunas_categoricas_nao_ordenadas = [
    'BusinessTravel',
    'Department',
    'EducationField',
    'Gender',
    'JobRole',
    'MaritalStatus',
    'OverTime'
]

colunas_categoricas_ordenadas = [
    'Education',
    'EnvironmentSatisfaction',
    'JobSatisfaction',
    'JobInvolvement',
    'JobLevel',
    'PerformanceRating',
    'RelationshipSatisfaction',
    'StockOptionLevel',
    'WorkLifeBalance'
]

coluna_alvo = ['Attrition']

colunas_numericas = [
    coluna for coluna in df.columns if coluna not in (
        colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas + coluna_alvo
    )
]
colunas_numericas

# para encontrar os restantes das colunas que sobraram usamos o codigo acima que e um List Comprehention (posso voltar no modulo do Python basico
# para revisar se eu quiser)
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'HourlyRate',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
for coluna in (colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas):
    print(f'{coluna}: {df[coluna].unique()}')
# Out:
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department: ['Sales' 'Research & Development' 'Human Resources']
# EducationField: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender: ['Female' 'Male']
# JobRole: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus: ['Single' 'Married' 'Divorced']
# OverTime: ['Yes' 'No']
# Education: [2 1 4 3 5]
# EnvironmentSatisfaction: [2 3 4 1]
# JobSatisfaction: [4 2 3 1]
# JobInvolvement: [3 2 4 1]
# JobLevel: [2 1 3 4 5]
# PerformanceRating: [3 4]
# RelationshipSatisfaction: [1 4 2 3]
# StockOptionLevel: [0 1 3 2]
# WorkLifeBalance: [1 3 2 4]

# %%
# comecaremos com as categorias nao ordenadas (que sao as primeriras da lista acima com os valores em Texto

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
# aqui vamos alterar o dtype das colunas nao categorizadas para 'category' como pode ser na tabela info abaixo.
# a unica object que nao foi alterada foi ATTRITION que e a coluna alvo
# o motivo de comercarmos com o tipo nao categorico e principalmente pq alerando para category o memory usage diminui como pode ser verificado
# no final das 2 tabelas (402.1+ KB > 332.9+ KB), as operacaoes tbm ficam um pouco mais rapidas

for coluna in colunas_categoricas_nao_ordenadas:
    df[coluna] = df[coluna].astype('category')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
# ...

# %%
# aqui estamos selecionando so os tipos=category que acabamos de alterar na tabela acima. O metodo e .select_dtypes
# Aula 29 de 47: IBM (se quiser entender melhor pq usar category para salvar memoria)
for coluna in df.select_dtypes(include='category'):
    print(f'{coluna}')
    print(f'{coluna}.cat.categories: {df[coluna].cat.categories}')
    print(f'{coluna}.cat.ordered: {df[coluna].cat.ordered}')
    print(f'{coluna}.cat.codes: {df[coluna].cat.codes.unique()}')
    print()
# Out:
# BusinessTravel
# BusinessTravel.cat.categories: Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# BusinessTravel.cat.ordered: False
# BusinessTravel.cat.codes: [2 1 0]
#
# Department
# Department.cat.categories: Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# Department.cat.ordered: False
# Department.cat.codes: [2 1 0]
#
# EducationField
# EducationField.cat.categories: Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# EducationField.cat.ordered: False
# EducationField.cat.codes: [1 4 3 2 5 0]
#
# Gender
# Gender.cat.categories: Index(['Female', 'Male'], dtype='object')
# Gender.cat.ordered: False
# Gender.cat.codes: [0 1]
#
# JobRole
# JobRole.cat.categories: Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
# ...

# %%
# fazendo uma pequena analise geral em graficos

df['Attrition'].value_counts()

# temos muito mais valores Nao que Sim conderado um Desbalanceamento
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['Attrition'].value_counts().plot(kind='bar'); # ; para deixar o grafico mais limpo
# Out:
# <Axes: xlabel='Attrition'>

# %%
df['Attrition'].value_counts().plot(kind='bar', color=['blue', 'red'])
# Out:
# <Axes: xlabel='Attrition'>

# %%
df['Attrition'].value_counts(normalize=True).plot(kind='bar', color=['blue', 'red'])

# (normalize=True) escala percentual
# Out:
# <Axes: xlabel='Attrition'>

# %%
df['Department'].value_counts().plot(kind='bar');

# %%
# Agora podemos comecar com agrupamentos
# contagem de fruncionario por departamento considerando Attrition

df.groupby(['Department', 'Attrition']).size()

#primeira maneira de fazer usando groupby
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\4059374694.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Department', 'Attrition']).size()
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# dtype: int64

# %%
# Possivel tbm fazer usando uma Pivot Table

df.pivot_table(index='Department', columns='Attrition', aggfunc='size')
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1961585006.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='Department', columns='Attrition', aggfunc='size')
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
# Para fazer contagem no pandas como fazemos acima e possivel fazer de outra forma atravez do CROSSTAB que e mais intuitiva

pd.crosstab(df['Department'], df['Attrition'])
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
# para pegar as percentagem
# da para analizar a percentem dos NO para cada departamento (coluna y) ou a porcentagem do Sim e Nao de cada departamento (coluna x)

pd.crosstab(df['Department'], df['Attrition'], normalize='index')

# por indice:
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278

# %%
pd.crosstab(df['Department'], df['Attrition'], normalize='columns')

# por coluna:
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.041363  0.050633
# Research & Development  0.671533  0.561181
# Sales                   0.287105  0.388186

# %%
# varias conclusoes podem ser tiradas com essas 2 ultimas tabelas. Uma delas e que a pocentagem YES que saiu do departamento de Research & 
# Development e baixa ao contrario do que se pode interpretar a primeira vista
# importante veificar numeros absolutos e porcentage. Como R&D tem muitos funciorios pode ser que tenha mais pessoas saindo.

# %%
# e importante destascar os valores a serem apresentados (usar biblioteca matplotlib)
# Colormaps: https://matplotlib.org/stable/users/explain/colors/colormaps.html
# #RdYlGn in the code was taken from the site, it is a code for the color.
import matplotlib.pyplot

pd.crosstab(df['Department'], df['Attrition'], normalize='index').style.background_gradient(cmap='RdYlGn', axis='columns')
# Out:
# <style type="text/css">
# #T_89076_row0_col0, #T_89076_row1_col0, #T_89076_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_89076_row0_col1, #T_89076_row1_col1, #T_89076_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_89076">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_89076_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_89076_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89076_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_89076_row0_col0" class="data row0 col0" >0.809524</td>
#       <td id="T_89076_row0_col1" class="data row0 col1" >0.190476</td>
#     </tr>
# ...

# %%
# agora com index, como sao 3 valores tem 3 cores, mas fica um pouco confuso, entao melhor o de cima.

pd.crosstab(df['Department'], df['Attrition'], normalize='index').style.background_gradient(cmap='RdYlGn', axis='index')
# Out:
# <style type="text/css">
# #T_c7114_row0_col0 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_c7114_row0_col1 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_c7114_row1_col0, #T_c7114_row2_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c7114_row1_col1, #T_c7114_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c7114">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_c7114_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_c7114_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7114_level0_row0" class="row_heading level0 row0" >Human Resources</th>
# ...

# %%
pd.crosstab(df['Department'], df['Attrition'], margins=True, margins_name='Total')

# margins=True para adicionar o total por linha e coluna. margins_name='Total' para alterar ALL para TOTAL
# Out:
# Attrition                 No  Yes  Total
# Department
# Human Resources           51   12     63
# Research & Development   828  133    961
# Sales                    354   92    446
# Total                   1233  237   1470

# %%
pd.crosstab(df['Department'], df['Attrition']).plot(kind='bar');

# %%
# coluna MonthlyIncome sera usada para os agrupamentos
# salarios por departamento

df.groupby('Department')['MonthlyIncome'].mean()
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\669092555.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Department')['MonthlyIncome'].mean()
# Department
# Human Resources           6654.507937
# Research & Development    6281.252862
# Sales                     6959.172646
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby('Department')['MonthlyIncome'].mean().plot(kind='bar')
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1726342721.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Department')['MonthlyIncome'].mean().plot(kind='bar')
# <Axes: xlabel='Department'>

# %%
df.groupby(['Department', 'Attrition'])['MonthlyIncome'].mean()

# pode se verificar abaixo que a media salarial influencia a saida dos funcionarios, pelo menos a principio vendo a tabela abaixo
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\3293010319.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Department', 'Attrition'])['MonthlyIncome'].mean()
# Department              Attrition
# Human Resources         No           7345.980392
#                         Yes          3715.750000
# Research & Development  No           6630.326087
#                         Yes          4108.075188
# Sales                   No           7232.240113
#                         Yes          5908.456522
# Name: MonthlyIncome, dtype: float64

# %%
# agora usando metodo pivot, so p treinar

df.pivot_table(index='Department', columns='Attrition', values='MonthlyIncome')

# pode se verificar abaixo que a media salarial influencia a saida dos funcionarios, pelo menos a principio vendo a tabela abaixo
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\2313876692.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='Department', columns='Attrition', values='MonthlyIncome')
# Attrition                        No          Yes
# Department
# Human Resources         7345.980392  3715.750000
# Research & Development  6630.326087  4108.075188
# Sales                   7232.240113  5908.456522

# %%
df.pivot_table(index='Department', columns='Attrition', values='MonthlyIncome').style.background_gradient(cmap='RdYlGn', axis='columns')
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\3141930288.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='Department', columns='Attrition', values='MonthlyIncome').style.background_gradient(cmap='RdYlGn', axis='columns')
# <style type="text/css">
# #T_5da07_row0_col0, #T_5da07_row1_col0, #T_5da07_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_5da07_row0_col1, #T_5da07_row1_col1, #T_5da07_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5da07">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_5da07_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_5da07_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
# ...

# %%
df.pivot_table(index='Department', columns='Attrition', values='MonthlyIncome').plot(kind='bar')

# no grafico abaixo pode se assumir q a media q sairam a media se salrio e menor
# os que ficam na empresa, nao tem uma diferenca muito grande entre os departmentos, entao esse grafico a principio ainda e simplista 
# considerando que vamos analisar outros parametros
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\257873076.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='Department', columns='Attrition', values='MonthlyIncome').plot(kind='bar')
# <Axes: xlabel='Department'>

# %%
df.groupby('JobRole')['MonthlyIncome'].mean()
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1916373840.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('JobRole')['MonthlyIncome'].mean()
# JobRole
# Healthcare Representative     7528.763359
# Human Resources               4235.750000
# Laboratory Technician         3237.169884
# Manager                      17181.676471
# Manufacturing Director        7295.137931
# Research Director            16033.550000
# Research Scientist            3239.972603
# Sales Executive               6924.279141
# Sales Representative          2626.000000
# Name: MonthlyIncome, dtype: float64

# %%
# uma analise melhor com pouco mais de insight (em relacao a analise por departamento)

df.groupby(['JobRole', 'Attrition'])['MonthlyIncome'].mean()
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1876095623.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole', 'Attrition'])['MonthlyIncome'].mean()
# JobRole                    Attrition
# Healthcare Representative  No            7453.557377
#                            Yes           8548.222222
# Human Resources            No            4391.750000
#                            Yes           3715.750000
# Laboratory Technician      No            3337.223350
#                            Yes           2919.258065
# Manager                    No           17201.484536
#                            Yes          16797.400000
# Manufacturing Director     No            7289.925926
#                            Yes           7365.500000
# ...

# %%
# media de salario por cargo e nivel (maior granulidade em relacao a cargo e mais ainda em relacao departamento),
# estamos afundalando.

df.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean()

# NaN > not a number ou ausencia
# Constatamos maior o nivel maior a media salarial
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1988690295.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean()
# JobRole                    JobLevel
# Healthcare Representative  1                    NaN
#                            2            5865.346154
#                            3            9363.954545
#                            4           12973.000000
#                            5                    NaN
# Human Resources            1            2733.212121
#                            2            5563.461538
#                            3            9623.000000
#                            4                    NaN
#                            5                    NaN
# ...

# %%
# agora transformar em um dataframe, assim e possivel aplicar um estilo

df.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean().to_frame()
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\2147422715.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean().to_frame()
#                                     MonthlyIncome
# JobRole                   JobLevel
# Healthcare Representative 1                   NaN
#                           2           5865.346154
#                           3           9363.954545
#                           4          12973.000000
#                           5                   NaN
# Human Resources           1           2733.212121
#                           2           5563.461538
#                           3           9623.000000
#                           4                   NaN
#                           5                   NaN
# ...

# %%
df.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean().to_frame().style.background_gradient(cmap='RdYlGn', axis='index')

# podemos verificar os maiores e menores salarios de acordo com a cor. Mas nao vimos ainda a questao do attrition. O salario de vendas
# e baixo mas poder ser tbm q tenha a questao de comissao
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1881514082.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole', 'JobLevel'])['MonthlyIncome'].mean().to_frame().style.background_gradient(cmap='RdYlGn', axis='index')
# <style type="text/css">
# #T_b933e_row0_col0, #T_b933e_row4_col0, #T_b933e_row8_col0, #T_b933e_row9_col0, #T_b933e_row13_col0, #T_b933e_row14_col0, #T_b933e_row15_col0, #T_b933e_row16_col0, #T_b933e_row20_col0, #T_b933e_row24_col0, #T_b933e_row25_col0, #T_b933e_row26_col0, #T_b933e_row33_col0, #T_b933e_row34_col0, #T_b933e_row35_col0, #T_b933e_row39_col0, #T_b933e_row42_col0, #T_b933e_row43_col0, #T_b933e_row44_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_b933e_row1_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# ...

# %%
df.groupby(['JobRole', 'JobLevel', 'Attrition'])['MonthlyIncome'].mean()

# ... pois comeca a ficar mais longo entao interessante usar uma pivot table
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1623029174.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole', 'JobLevel', 'Attrition'])['MonthlyIncome'].mean()
# JobRole                    JobLevel  Attrition
# Healthcare Representative  1         No                   NaN
#                                      Yes                  NaN
#                            2         No           5828.280000
#                                      Yes          6792.000000
#                            3         No           9426.282051
#                                                      ...
# Sales Representative       3         Yes                  NaN
#                            4         No                   NaN
# ...

# %%
df.pivot_table(index=['JobRole', 'JobLevel'], columns='Attrition', values='MonthlyIncome')

# esse metodo deixa a tabela mais resumida
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\762407148.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index=['JobRole', 'JobLevel'], columns='Attrition', values='MonthlyIncome')
# Attrition                                     No           Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000
#                           3          9426.282051   8877.800000
#                           4         13073.500000  12169.000000
# Human Resources           1          2871.260870   2415.700000
#                           2          5563.461538           NaN
#                           3          9326.500000  10216.000000
# Laboratory Technician     1          2921.708333   2682.000000
#                           2          4394.000000   5084.200000
# ...

# %%
df.pivot_table(
    index=['JobRole', 'JobLevel'], columns='Attrition', values='MonthlyIncome'
).style.background_gradient(cmap='RdYlGn', axis='columns')

# diferenca entre salarios que sairam e q permaneceram. Sales Ex. e bem parecido, ja Sakes Representative level 2 a diferenca e bem grande.
# Mas sempre e bom rever a quantidade de funcionarios por departamento, pois a s vezes pode ser um unico funcionario quando tem diferencas
# amostrais muito grande
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1378583280.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# <style type="text/css">
# #T_92567_row0_col0, #T_92567_row1_col1, #T_92567_row2_col1, #T_92567_row3_col1, #T_92567_row4_col0, #T_92567_row4_col1, #T_92567_row5_col0, #T_92567_row6_col1, #T_92567_row7_col0, #T_92567_row8_col1, #T_92567_row9_col0, #T_92567_row10_col0, #T_92567_row10_col1, #T_92567_row11_col0, #T_92567_row12_col1, #T_92567_row13_col0, #T_92567_row14_col0, #T_92567_row14_col1, #T_92567_row15_col0, #T_92567_row15_col1, #T_92567_row16_col0, #T_92567_row16_col1, #T_92567_row17_col0, #T_92567_row18_col1, #T_92567_row19_col1, #T_92567_row20_col0, #T_92567_row20_col1, #T_92567_row21_col0, #T_92567_row22_col0, #T_92567_row23_col0, #T_92567_row24_col1, #T_92567_row25_col1 {
# ...

# %%
# entao adicionamos aggfunc=['mean', 'size']:

df.pivot_table(
    index=['JobRole', 'JobLevel'], columns='Attrition', values='MonthlyIncome', aggfunc=['mean', 'size']
)

# como vemos na primeira linha, apenas 3 de 75 sairam o q mostra q e um valor baixo e que pode ter sido por motivo de aposentadoria por exemplo
# No sales Executivo bastante gente saiu 197 vs 36 mesmo com salario mais alto o q pode demonstrar que pode haver alta concorrencia no depart. ou
# empresas concorrentes estao disposatas a pagar mais
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\3451430796.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\3451430796.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# ...

# %%
# limpar um pouco a tabela

df.pivot_table(
    index=['JobRole', 'JobLevel'], columns='Attrition', values='MonthlyIncome', aggfunc=['mean', 'size']
).dropna()
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\3437365755.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\3437365755.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# ...

# %%
# elimina a linha inteira q tem NAN, queremos so as linhas que contem ambas NAN em YEs e NO

df.pivot_table(
    index=['JobRole', 'JobLevel'], columns='Attrition', values='MonthlyIncome', aggfunc=['mean', 'size']
).dropna(how='all', subset=[('mean', 'No'),('mean', 'Yes')])

# .dropna(how='all', subset=[('mean', 'No'),('mean', 'Yes')]) > elimina todas as linhas que contem ambas NAN em YEs e NO
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1397580550.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1397580550.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# ...

# %%
df.pivot_table(
    index=['JobRole', 'JobLevel'], columns='Attrition', values='MonthlyIncome', aggfunc=['size']
)
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\319387726.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
#                                    size
# Attrition                            No Yes
# JobRole                   JobLevel
# Healthcare Representative 1           0   0
#                           2          75   3
#                           3          39   5
#                           4           8   1
#                           5           0   0
# Human Resources           1          23  10
#                           2          13   0
#                           3           4   2
#                           4           0   0
#                           5           0   0
# Laboratory Technician     1         144  56
#                           2          51   5
# ...

# %%
# usando crosstab com multiplo indice. ate agora usamos so com 2

pd.crosstab([df['JobRole'], df['JobLevel']], df['Attrition'])

# linhas com so 0 foram eliminadas, pois crosstab e uma contagem especifica de contagem diferente de 0
# aqui temos numeros absolutos
# Out:
# Attrition                            No  Yes
# JobRole                   JobLevel
# Healthcare Representative 2          75    3
#                           3          39    5
#                           4           8    1
# Human Resources           1          23   10
#                           2          13    0
#                           3           4    2
# Laboratory Technician     1         144   56
#                           2          51    5
#                           3           2    1
# Manager                   3          10    2
#                           4          47    0
#                           5          40    3
# Manufacturing Director    2          85    5
#                           3          40    5
#                           4          10    0
# Research Director         3          28    0
#                           4          26    0
#                           5          24    2
# Research Scientist        1         189   45
# ...

# %%
# agora com numeros relativos para fazer aquela diferenciacao. Por exmplo na terceira linha do HR 0.33 sairam mas vendo os numeros absolutos
# isso reoresenta um numero baixo em termos absolutos

pd.crosstab([df['JobRole'], df['JobLevel']], df['Attrition'], normalize='index').style.background_gradient(cmap='RdYlGn', axis='columns')

# nao teve nenhum, dpt com mais saida que permanencia, mas e interessante ter grandietes entre valores dentro de cada coluna
# Out:
# <style type="text/css">
# #T_c4833_row0_col0, #T_c4833_row1_col0, #T_c4833_row2_col0, #T_c4833_row3_col0, #T_c4833_row4_col0, #T_c4833_row5_col0, #T_c4833_row6_col0, #T_c4833_row7_col0, #T_c4833_row8_col0, #T_c4833_row9_col0, #T_c4833_row10_col0, #T_c4833_row11_col0, #T_c4833_row12_col0, #T_c4833_row13_col0, #T_c4833_row14_col0, #T_c4833_row15_col0, #T_c4833_row16_col0, #T_c4833_row17_col0, #T_c4833_row18_col0, #T_c4833_row19_col0, #T_c4833_row20_col0, #T_c4833_row21_col0, #T_c4833_row22_col0, #T_c4833_row23_col0, #T_c4833_row24_col0, #T_c4833_row25_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# ...

# %%
pd.crosstab(
    [df['JobRole'], 
    df['JobLevel']],
    df['Attrition'], normalize='index').style.background_gradient(cmap='RdYlGn', axis='columns', vmin=0, vmax=1)

# ter grandietes entre valores dentro de cada coluna
# Out:
# <style type="text/css">
# #T_19952_row0_col0 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_19952_row0_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_19952_row1_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_19952_row1_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_19952_row2_col0, #T_19952_row13_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_19952_row2_col1, #T_19952_row13_col1 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_19952_row3_col0 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_19952_row3_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_19952_row4_col0, #T_19952_row10_col0, #T_19952_row14_col0, #T_19952_row15_col0, #T_19952_row16_col0, #T_19952_row20_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# ...

# %%
# estamos fando de contagem podemos usar crossatab e vamos fazer analise agora por genero adicionando Margins para
# ver o total

pd.crosstab(df['Department'], df['Gender'], margins=True, margins_name='Total')
# Out:
# Gender                  Female  Male  Total
# Department
# Human Resources             20    43     63
# Research & Development     379   582    961
# Sales                      189   257    446
# Total                      588   882   1470

# %%
df.pivot_table(index=['Department', 'Gender'], columns='Attrition', aggfunc='size')

# Para uma analise em projeto de portfolio mesmo numero absoluto de 6 pessoas mas vem de um universo amostral diferente. Em HR sao 6 em 14
para Female e 6 para 37 em Male, a proporcao disso e diferente.
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\3759106145.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index=['Department', 'Gender'], columns='Attrition', aggfunc='size')
# Attrition                       No  Yes
# Department             Gender
# Human Resources        Female   14    6
#                        Male     37    6
# Research & Development Female  336   43
#                        Male    492   90
# Sales                  Female  151   38
#                        Male    203   54

# %%
pd.crosstab(df['JobRole'], df['Gender'], margins=True, margins_name='Total')
# Out:
# Gender                     Female  Male  Total
# JobRole
# Healthcare Representative      51    80    131
# Human Resources                16    36     52
# Laboratory Technician          85   174    259
# Manager                        47    55    102
# Manufacturing Director         72    73    145
# Research Director              33    47     80
# Research Scientist            114   178    292
# Sales Executive               132   194    326
# Sales Representative           38    45     83
# Total                         588   882   1470

# %%
df.pivot_table(index=['JobRole', 'Gender'], columns='Attrition', aggfunc='size')
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\1341048659.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index=['JobRole', 'Gender'], columns='Attrition', aggfunc='size')
# Attrition                          No  Yes
# JobRole                   Gender
# Healthcare Representative Female   46    5
#                           Male     76    4
# Human Resources           Female   10    6
#                           Male     30    6
# Laboratory Technician     Female   69   16
#                           Male    128   46
# Manager                   Female   45    2
#                           Male     52    3
# Manufacturing Director    Female   68    4
#                           Male     67    6
# Research Director         Female   32    1
#                           Male     46    1
# ...

# %%
# agora media salarial por nivel educacional

df.groupby('Education')['MonthlyIncome'].mean()
# Out:
# Education
# 1    5640.570588
# 2    6226.645390
# 3    6517.263986
# 4    6832.402010
# 5    8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
# vamos criar um dicionario para adicionar os nomes de cada nivel de educacao na tabela

mapeamento_educacao = {
    1: 'Below College',
    2: 'College',
    3: 'Bachelor',
    4: 'Master',
    5: 'PhD',
}

# %%
df.groupby('Education')['MonthlyIncome'].mean().rename(index=mapeamento_educacao)
# Out:
# Education
# Below College    5640.570588
# College          6226.645390
# Bachelor         6517.263986
# Master           6832.402010
# PhD              8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby('Education').size().rename(index=mapeamento_educacao)
# Out:
# Education
# Below College    170
# College          282
# Bachelor         572
# Master           398
# PhD               48
# dtype: int64

# %%
df.groupby(['Education', 'Attrition']).size().rename(index=mapeamento_educacao)
# Out:
# Education      Attrition
# Below College  No           139
#                Yes           31
# College        No           238
#                Yes           44
# Bachelor       No           473
#                Yes           99
# Master         No           340
#                Yes           58
# PhD            No            43
#                Yes            5
# dtype: int64

# %%
# pode ser com crosstab tbm..pouco mais facil de ler e entender

pd.crosstab(df['Education'], df['Attrition'], margins=True, margins_name='Total').rename(index=mapeamento_educacao)
# Out:
# Attrition        No  Yes  Total
# Education
# Below College   139   31    170
# College         238   44    282
# Bachelor        473   99    572
# Master          340   58    398
# PhD              43    5     48
# Total          1233  237   1470

# %%
pd.crosstab(
    df['Education'],
    df['Attrition'],
    margins=True,
    margins_name='Total',
    normalize='index', # para saber a porporcao por nivel educacional
).rename(index=mapeamento_educacao)
# Out:
# Attrition            No       Yes
# Education
# Below College  0.817647  0.182353
# College        0.843972  0.156028
# Bachelor       0.826923  0.173077
# Master         0.854271  0.145729
# PhD            0.895833  0.104167
# Total          0.838776  0.161224

# %%
# agora outro universo amostral

pd.crosstab(
    df['Education'],
    df['Attrition'],
    margins=True,
    margins_name='Total',
    normalize='columns',
).rename(index=mapeamento_educacao)

# %%
# por departamento, numeros absolutos

pd.crosstab(df['Education'], df['JobRole'], margins=True, margins_name='Total').rename(index=mapeamento_educacao)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                         15                5
# College                               21               12
# Bachelor                              48               22
# Master                                44               10
# PhD                                    3                3
# Total                                131               52
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below College                     35        9                      15
# College                           57       19                      33
# Bachelor                         104       40                      54
# Master                            58       29                      38
# PhD                                5        5                       5
# Total                            259      102                     145
#
# ...

# %%
# por departamento, numeros relativos

pd.crosstab(df['Education'], df['JobRole'], margins=True, margins_name='Total', normalize='index').rename(index=mapeamento_educacao)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                   0.088235         0.029412
# College                         0.074468         0.042553
# Bachelor                        0.083916         0.038462
# Master                          0.110553         0.025126
# PhD                             0.062500         0.062500
# Total                           0.089116         0.035374
#
# JobRole        Laboratory Technician   Manager  Manufacturing Director  \
# Education
# Below College               0.205882  0.052941                0.088235
# College                     0.202128  0.067376                0.117021
# Bachelor                    0.181818  0.069930                0.094406
# Master                      0.145729  0.072864                0.095477
# PhD                         0.104167  0.104167                0.104167
# Total                       0.176190  0.069388                0.098639
#
# ...

# %%
# agora por coluna

pd.crosstab(df['Education'], df['JobRole'], margins=True, margins_name='Total', normalize='columns').rename(index=mapeamento_educacao)

# como vimos que no geral a empresa e composta por bacharelados e mestrados podemos ver por departamento se esse e a situacao
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                   0.114504         0.096154
# College                         0.160305         0.230769
# Bachelor                        0.366412         0.423077
# Master                          0.335878         0.192308
# PhD                             0.022901         0.057692
#
# JobRole        Laboratory Technician   Manager  Manufacturing Director  \
# Education
# Below College               0.135135  0.088235                0.103448
# College                     0.220077  0.186275                0.227586
# Bachelor                    0.401544  0.392157                0.372414
# Master                      0.223938  0.284314                0.262069
# PhD                         0.019305  0.049020                0.034483
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College             0.0875            0.126712         0.082822
# ...

# %%
# para eliminar as casas decimais

pd.crosstab(df['Education'],
            df['JobRole'], margins=True, margins_name='Total', normalize='columns').rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                      11.45             9.62
# College                            16.03            23.08
# Bachelor                           36.64            42.31
# Master                             33.59            19.23
# PhD                                 2.29             5.77
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below College                  13.51     8.82                   10.34
# College                        22.01    18.63                   22.76
# Bachelor                       40.15    39.22                   37.24
# Master                         22.39    28.43                   26.21
# PhD                             1.93     4.90                    3.45
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College               8.75               12.67             8.28
# ...

# %%
# Verificar por job level por indice (por linha)

pd.crosstab(df['Education'],
            df['JobLevel'], margins=True, margins_name='Total', normalize='index').rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobLevel           1      2      3      4     5
# Education
# Below College  52.35  27.65  11.76   4.71  3.53
# College        33.33  44.33  11.70   6.03  4.61
# Bachelor       40.38  29.90  17.13   7.69  4.90
# Master         30.40  42.96  14.57   7.04  5.03
# PhD            16.67  41.67  18.75  18.75  4.17
# Total          36.94  36.33  14.83   7.21  4.69

# %%
# Verificar por job level por columns (por colunas)

pd.crosstab(df['Education'],
            df['JobLevel'], margins=True, margins_name='Total', normalize='columns').rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobLevel           1      2      3      4      5  Total
# Education
# Below College  16.39   8.80   9.17   7.55   8.70  11.56
# College        17.31  23.41  15.14  16.04  18.84  19.18
# Bachelor       42.54  32.02  44.95  41.51  40.58  38.91
# Master         22.28  32.02  26.61  26.42  28.99  27.07
# PhD             1.47   3.75   4.13   8.49   2.90   3.27

# %%
# podemos entao juntar as informacoes tendo codigos multi indices

pd.crosstab([df['JobRole'], df['Education']],
            df['JobLevel'], margins=True, margins_name='Total').rename(index=mapeamento_educacao)
# Out:
# JobLevel                                   1    2    3    4   5  Total
# JobRole                   Education
# Healthcare Representative Below College    0    8    5    2   0     15
#                           College          0   15    4    2   0     21
#                           Bachelor         0   25   20    3   0     48
#                           Master           0   28   15    1   0     44
#                           PhD              0    2    0    1   0      3
# Human Resources           Below College    4    1    0    0   0      5
#                           College          9    2    1    0   0     12
#                           Bachelor        13    6    3    0   0     22
#                           Master           6    2    2    0   0     10
#                           PhD              1    2    0    0   0      3
# Laboratory Technician     Below College   32    3    0    0   0     35
#                           College         39   16    2    0   0     57
# ...

# %%
# agora incluindo attrition

pd.crosstab([df['JobRole'], df['Education'], df['Attrition']],
            df['JobLevel'], margins=True, margins_name='Total').rename(columns=mapeamento_educacao)
# Out:
# JobLevel                                       Below College  College  \
# JobRole                   Education Attrition
# Healthcare Representative 1         No                     0        7
#                                     Yes                    0        1
#                           2         No                     0       13
#                                     Yes                    0        2
#                           3         No                     0       25
# ...                                                      ...      ...
# Sales Representative      3         No                    16        0
#                                     Yes                   15        1
#                           4         No                    11        2
#                                     Yes                    3        0
# Total                                                    543      534
#
# JobLevel                                       Bachelor  Master  PhD  Total
# ...

# %%
# veremos idade, comecar pela media
# *lembrar q media e importante mas pode ser afetada por alguns valores extremos muito altos ou muito baixos.

df.groupby('Attrition')['Age'].mean()

# Maior parte que saiu da empresa tinha idade menor
# Out:
# Attrition
# No     37.561233
# Yes    33.607595
# Name: Age, dtype: float64

# %%
df.groupby('Attrition')['Age'].value_counts(bins=10)
# Out:
# Attrition  Age
# No         (34.8, 39.0]                  267
#            (30.6, 34.8]                  215
#            (26.4, 30.6]                  180
#            (39.0, 43.2]                  160
#            (43.2, 47.4]                  116
#            (47.4, 51.6]                   81
#            (22.2, 26.4]                   76
#            (51.6, 55.8]                   69
#            (55.8, 60.0]                   39
#            (17.956999999999997, 22.2]     30
# Yes        (30.0, 34.0]                   50
#            (26.0, 30.0]                   44
#            (22.0, 26.0]                   29
#            (17.959, 22.0]                 27
#            (34.0, 38.0]                   24
#            (38.0, 42.0]                   19
#            (42.0, 46.0]                   14
#            (46.0, 50.0]                   12
#            (54.0, 58.0]                   11
#            (50.0, 54.0]                    7
# Name: count, dtype: int64

# %%
# ordenando

df.groupby('Attrition')['Age'].value_counts(bins=10).sort_index()
# Out:
# Attrition  Age
# No         (17.956999999999997, 22.2]     30
#            (22.2, 26.4]                   76
#            (26.4, 30.6]                  180
#            (30.6, 34.8]                  215
#            (34.8, 39.0]                  267
#            (39.0, 43.2]                  160
#            (43.2, 47.4]                  116
#            (47.4, 51.6]                   81
#            (51.6, 55.8]                   69
#            (55.8, 60.0]                   39
# Yes        (17.959, 22.0]                 27
#            (22.0, 26.0]                   29
#            (26.0, 30.0]                   44
#            (30.0, 34.0]                   50
#            (34.0, 38.0]                   24
#            (38.0, 42.0]                   19
#            (42.0, 46.0]                   14
#            (46.0, 50.0]                   12
#            (50.0, 54.0]                    7
#            (54.0, 58.0]                   11
# Name: count, dtype: int64

# %%
# esse dataset e bastante desbalanciado como mostra a diferenca abaixo entao faremos uma normalizacao

df.groupby('Attrition')['Age'].size()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: Age, dtype: int64

# %%
# faremos uma normalizacao para ter nocao das porcentagem

df.groupby('Attrition')['Age'].value_counts(bins=10, normalize=True).mul(100).round(1).sort_index()
# Out:
# Attrition  Age
# No         (17.956999999999997, 22.2]     2.4
#            (22.2, 26.4]                   6.2
#            (26.4, 30.6]                  14.6
#            (30.6, 34.8]                  17.4
#            (34.8, 39.0]                  21.7
#            (39.0, 43.2]                  13.0
#            (43.2, 47.4]                   9.4
#            (47.4, 51.6]                   6.6
#            (51.6, 55.8]                   5.6
#            (55.8, 60.0]                   3.2
# Yes        (17.959, 22.0]                11.4
#            (22.0, 26.0]                  12.2
#            (26.0, 30.0]                  18.6
#            (30.0, 34.0]                  21.1
#            (34.0, 38.0]                  10.1
#            (38.0, 42.0]                   8.0
#            (42.0, 46.0]                   5.9
#            (46.0, 50.0]                   5.1
#            (50.0, 54.0]                   3.0
#            (54.0, 58.0]                   4.6
# ...

# %%
df.hist(column='Age', by='Attrition')

# diferenca no grafico e uma queda abrupta do q saem a partir do 40 anos indicando que poucas pessoas saem depois dessa idade
# Out:
# array([<Axes: title={'center': 'No'}>, <Axes: title={'center': 'Yes'}>],
#       dtype=object)

# %%
# nao precisamos usar 10 intervalos, pode usar 5 por exemplo mas tomar cuidado pois as vezes nao fica muito representativo. Padrao do Pandas e 10

df.hist(column='Age', by='Attrition', bins=5)
# Out:
# array([<Axes: title={'center': 'No'}>, <Axes: title={'center': 'Yes'}>],
#       dtype=object)

# %%
# nova categoria ordenada PANDAS CUT com base em uma categoria numerica (Idade por exemplo pode ter um numero inteiro (41 anos) ou continuo 
# (41 e 4 meses))

faixas_idade = [0, 20, 30, 50, float('inf')] # (0-20], (20-30], (30-50], (50+]
rotulos = 'Adolescente', 'Jovem Adulto', 'Adulto medio', 'Adulto senior'
# acima, criando intervalo de idades, com 50 acima

# abaixo, criando uma nova coluna
df['FaixaEtaria'] = pd.cut(df['Age'], bins=faixas_idade, labels=rotulos)

df[['Age', 'FaixaEtaria']].head(20)
# Out:
#     Age    FaixaEtaria
# 0    41   Adulto medio
# 1    49   Adulto medio
# 2    37   Adulto medio
# 3    33   Adulto medio
# 4    27   Jovem Adulto
# 5    32   Adulto medio
# 6    59  Adulto senior
# 7    30   Jovem Adulto
# 8    38   Adulto medio
# 9    36   Adulto medio
# 10   35   Adulto medio
# 11   29   Jovem Adulto
# 12   31   Adulto medio
# 13   34   Adulto medio
# 14   28   Jovem Adulto
# 15   29   Jovem Adulto
# 16   32   Adulto medio
# 17   22   Jovem Adulto
# 18   53  Adulto senior
# 19   38   Adulto medio

# %%
df[['Age', 'FaixaEtaria']].tail(20)
# Out:
#       Age   FaixaEtaria
# 1450   35  Adulto medio
# 1451   38  Adulto medio
# 1452   50  Adulto medio
# 1453   36  Adulto medio
# 1454   45  Adulto medio
# 1455   40  Adulto medio
# 1456   35  Adulto medio
# 1457   40  Adulto medio
# 1458   35  Adulto medio
# 1459   29  Jovem Adulto
# 1460   29  Jovem Adulto
# 1461   50  Adulto medio
# 1462   39  Adulto medio
# 1463   31  Adulto medio
# 1464   26  Jovem Adulto
# 1465   36  Adulto medio
# 1466   39  Adulto medio
# 1467   27  Jovem Adulto
# 1468   49  Adulto medio
# 1469   34  Adulto medio

# %%
df.info()

# podemos ver q a coluna nova criada e classificada como categorica
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
# ...

# %%
# peguei essa formula de cima. E podemos ver a coluna nova no final adicionada e podemos verificar que e uma coluna categorizada. Isso quer
# dizer que e possivel ordena la como faremos mais abaixo

for coluna in df.select_dtypes(include='category'):
    print(f'{coluna}')
    print(f'{coluna}.cat.categories: {df[coluna].cat.categories}')
    print(f'{coluna}.cat.ordered: {df[coluna].cat.ordered}')
    print(f'{coluna}.cat.codes: {df[coluna].cat.codes.unique()}')
    print()
# Out:
# BusinessTravel
# BusinessTravel.cat.categories: Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# BusinessTravel.cat.ordered: False
# BusinessTravel.cat.codes: [2 1 0]
#
# Department
# Department.cat.categories: Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# Department.cat.ordered: False
# Department.cat.codes: [2 1 0]
#
# EducationField
# EducationField.cat.categories: Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# EducationField.cat.ordered: False
# EducationField.cat.codes: [1 4 3 2 5 0]
#
# Gender
# Gender.cat.categories: Index(['Female', 'Male'], dtype='object')
# Gender.cat.ordered: False
# Gender.cat.codes: [0 1]
#
# JobRole
# JobRole.cat.categories: Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
# ...

# %%
df['FaixaEtaria'].value_counts()
# Out:
# FaixaEtaria
# Adulto medio     941
# Jovem Adulto     358
# Adulto senior    143
# Adolescente       28
# Name: count, dtype: int64

# %%
df['FaixaEtaria'].value_counts().sort_index()

# pelo fato da coluna ser categorizada e possivel ordena la como podemos ver abaixo. Ele consegue identificar a ordem sem ver a ordem
# alfabetica. O CUT identifica a ordem dos rotulos e nao alfabetica da faixa etaria
# Out:
# FaixaEtaria
# Adolescente       28
# Jovem Adulto     358
# Adulto medio     941
# Adulto senior    143
# Name: count, dtype: int64

# %%
df['FaixaEtaria'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='FaixaEtaria'>

# %%
# como e o attrition em relacao a essas idades? Pode ser feita de forma como um grafico mostrado acima ou um Crosstab

pd.crosstab(df['FaixaEtaria'], df['Attrition'], normalize='index').mul(100).round(1).style.background_gradient(cmap='RdYlGn', axis='columns')

#vemos que a unica faixa que o Yes e maior que o Nao e a faixa Adolescente. As vezes essa forma fica mais facil de um publico nao tecnico
# entender
# Out:
# <style type="text/css">
# #T_5a66d_row0_col0, #T_5a66d_row1_col1, #T_5a66d_row2_col1, #T_5a66d_row3_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_5a66d_row0_col1, #T_5a66d_row1_col0, #T_5a66d_row2_col0, #T_5a66d_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5a66d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_5a66d_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_5a66d_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FaixaEtaria</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a66d_level0_row0" class="row_heading level0 row0" >Adolescente</th>
#       <td id="T_5a66d_row0_col0" class="data row0 col0" >42.900000</td>
# ...

# %%
# concluindo pandas CUT vai ser muito importante pois podemos criar nossa propria categoria, pois como no nosso exemplo colocamos nomes
# nas categorias (adolescente..) sendo mais compreendido que um histograma

# %%
colunas_categoricas_ordenadas.append('FaixaEtaria')
colunas_categoricas_ordenadas
# Out:
# ['Education',
#  'EnvironmentSatisfaction',
#  'JobSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'WorkLifeBalance',
#  'FaixaEtaria',
#  'FaixaEtaria',
#  'FaixaEtaria']

# %%
df[colunas_numericas].hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'DailyRate'}>,
#         <Axes: title={'center': 'DistanceFromHome'}>,
#         <Axes: title={'center': 'HourlyRate'}>],
#        [<Axes: title={'center': 'MonthlyIncome'}>,
#         <Axes: title={'center': 'MonthlyRate'}>,
#         <Axes: title={'center': 'NumCompaniesWorked'}>,
#         <Axes: title={'center': 'PercentSalaryHike'}>],
#        [<Axes: title={'center': 'TotalWorkingYears'}>,
#         <Axes: title={'center': 'TrainingTimesLastYear'}>,
#         <Axes: title={'center': 'YearsAtCompany'}>,
#         <Axes: title={'center': 'YearsInCurrentRole'}>],
#        [<Axes: title={'center': 'YearsSinceLastPromotion'}>,
#         <Axes: title={'center': 'YearsWithCurrManager'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
# adiciona ; para eliminar os texto no comeco

df[colunas_numericas].hist();

# %%
# aumentando o tamanho dos graficos

df[colunas_numericas].hist(figsize=(15,10));

# %%
#agora outro tipo de grafico: BoxPlot(sao construidos a partir do conceito de quartis)

# %%
df['DistanceFromHome'].hist()
# Out:
# <Axes: >

# %%
df.boxplot(column='DistanceFromHome', vert=False, grid=False)
# Out:
# <Axes: >

# %%
df['DistanceFromHome'].describe()

# olhando para o boxplot e as info abaixo, podemos ver que 25% esta em 2, 50% em 7 e 75% em 14
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
# para adicionar a media
# o triangulo representa a media

df.boxplot(column='DistanceFromHome', vert=False, grid=False, showmeans=True)
# Out:
# <Axes: >

# %%
df.groupby(['Gender', 'Attrition'])['Age'].describe()
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\3667313215.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Gender', 'Attrition'])['Age'].describe()
#                   count       mean       std   min   25%   50%    75%   max
# Gender Attrition
# Female No         501.0  38.155689  9.001762  18.0  31.0  37.0  45.00  60.0
#        Yes         87.0  32.574713  9.385333  18.0  27.0  31.0  36.50  58.0
# Male   No         732.0  37.154372  8.792917  18.0  31.0  36.0  43.00  60.0
#        Yes        150.0  34.206667  9.842584  18.0  28.0  32.0  39.75  58.0

# %%
# considerando o boxplot tem uma profunda relacao com quartis podemos..ate pq chega um momento analise em tabela comeca a ficar meio limitada e boxplot pode ajudar
# como vemos abaixo contagem porcentual 

df.boxplot(column='Age', by=['Gender', 'Attrition'], grid=False, showmeans=True)
# Out:
# <Axes: title={'center': 'Age'}, xlabel='[Gender, Attrition]'>

# %%
# conseguimos corroborar que os niveis mais altos da empresa e ocupada por pessoas mais seniors?

df.groupby('JobLevel')['Age'].describe()
# Out:
#           count       mean       std   min   25%   50%   75%   max
# JobLevel
# 1         543.0  32.524862  8.463882  18.0  27.0  31.0  37.0  59.0
# 2         534.0  36.599251  7.503875  22.0  31.0  35.5  41.0  60.0
# 3         218.0  40.087156  8.114771  27.0  34.0  38.0  46.0  60.0
# 4         106.0  47.537736  6.485404  29.0  43.0  48.0  53.0  59.0
# 5          69.0  47.753623  5.778779  39.0  42.0  48.0  52.0  60.0

# %%
df.groupby(['Gender', 'Attrition'])['JobSatisfaction'].describe()
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\2118542832.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Gender', 'Attrition'])['JobSatisfaction'].describe()
#                   count      mean       std  min  25%  50%  75%  max
# Gender Attrition
# Female No         501.0  2.728543  1.098255  1.0  2.0  3.0  4.0  4.0
#        Yes         87.0  2.425287  1.052485  1.0  2.0  2.0  3.0  4.0
# Male   No         732.0  2.812842  1.089283  1.0  2.0  3.0  4.0  4.0
#        Yes        150.0  2.493333  1.157100  1.0  1.0  3.0  3.0  4.0

# %%
df.boxplot(column='JobSatisfaction', by=['Gender', 'Attrition'], grid=False, showmeans=True)
# Out:
# <Axes: title={'center': 'JobSatisfaction'}, xlabel='[Gender, Attrition]'>

# %%
df.boxplot(column='Age', by='JobLevel', grid=False, showmeans=True)

# vemos que as medianas estao aumentando.
# as faixas nivel 1 e 2 tem outliers comm idade avancada
# Out:
# <Axes: title={'center': 'Age'}, xlabel='JobLevel'>

# %%
df.groupby(['JobRole', 'Gender', 'JobLevel'])['MonthlyIncome'].describe()
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\3017327641.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['JobRole', 'Gender', 'JobLevel'])['MonthlyIncome'].describe()
#                                            count          mean          std  \
# JobRole                   Gender JobLevel
# Healthcare Representative Female 2          31.0   5882.838710  1601.010475
#                                  3          17.0   9123.058824  1305.181188
#                                  4           3.0  13888.000000   133.371661
#                           Male   2          47.0   5853.808511  1026.214204
#                                  3          27.0   9515.629630  1312.786735
#                                  4           6.0  12515.500000  1165.564885
# ...

# %%
job_roles = df['JobRole'].unique()
job_roles

# essa variavel e util para fazer um loop for
# Out:
# ['Sales Executive', 'Research Scientist', 'Laboratory Technician', 'Manufacturing Director', 'Healthcare Representative', 'Manager', 'Sales Representative', 'Research Director', 'Human Resources']
# Categories (9, object): ['Healthcare Representative', 'Human Resources', 'Laboratory Technician', 'Manager', ..., 'Research Director', 'Research Scientist', 'Sales Executive', 'Sales Representative']

# %%
for job in job_roles:
    df[df['JobRole'] == job].boxplot(column='MonthlyIncome', by=['JobLevel', 'Gender'], grid=False, showmeans=True)

# 9 figuras pois temos 9 cargos

# %%
# as tabelas nao mostram o nome do cargo no titulo, uma forma de fazer isso e:
# A segundo forma de fazer plot no Pandas e mostrado abaixo:

for job in job_roles:
    df[df['JobRole'] == job].plot(kind='box', column='MonthlyIncome', by=['JobLevel', 'Gender'], grid=False, showmeans=True, title=job)
# Out:
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\636763970.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['JobRole'] == job].plot(kind='box', column='MonthlyIncome', by=['JobLevel', 'Gender'], grid=False, showmeans=True, title=job)
# C:\Users\c_buf\AppData\Local\Temp\ipykernel_21936\636763970.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['JobRole'] == job].plot(kind='box', column='MonthlyIncome', by=['JobLevel', 'Gender'], grid=False, showmeans=True, title=job)
# ...
